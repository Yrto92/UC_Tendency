.txt', 'GSM2932835_13450.txt', 'GSM2932814_Control8.txt', 'GSM2933006_11730.txt', 'GSM2933000_15259.txt', 'GSM2932926_13958.txt', 'GSM2932999_11516.txt', 'GSM2933014_2648.txt', 'GSM2932895_5244.txt', 'GSM2932892_3711.txt', 'GSM2932982_11827.txt', 'GSM2932973_1035.txt', 'GSM2932807_Control1.txt', 'GSM2932826_Control20.txt', 'GSM2932933_9687.txt', 'GSM2932978_2390.txt', 'GSM2932866_1321.txt', 'GSM2932996_2637.txt', 'GSM2932976_855.txt', 'GSM2933001_11542.txt', 'GSM2932940_14224.txt', 'GSM2932900_13308.txt', 'GSM2932898_12548.txt', 'GSM2932868_4205.txt', 'GSM2932934_12976.txt', 'GSM2932874_582.txt']

# %%
txt_list.sort(reverse = False)

# %%
txt_list

# %%
new_names = []

for i in txt_list:
  i = i.split('_')[0]
  new_names.append(i)

for i,j in zip(txt_list, new_names):
  j = pd.read_csv(i)

# %%
main_dataframe = pd.DataFrame(pd.read_table(txt_list[0]))
sf = pd.Series()
for i in range(0,len(txt_list)):
    data = pd.read_table(txt_list[i])
    if i == 0:
     df = pd.DataFrame(data)
     df = df.rename(columns={df.columns[1]: txt_list[i]}) #Rename value column to filename
     main_dataframe = df
     for col in main_dataframe.columns:
       name = col.split('_')[0]
       main_dataframe.rename(columns = {col : name}, inplace = True) #Leave onle the string that somes before the _ as acolumn name
    else:
     df = pd.DataFrame(data.iloc[:,1])
     df = df.rename(columns={df.columns[0]: txt_list[i]})
     main_dataframe = pd.concat([main_dataframe,df], axis = 1) # add only the value column (without the gene name column) to the dataframe
     for col in main_dataframe.columns:
       name = col.split('_')[0]
       main_dataframe.rename(columns = {col : name}, inplace = True)
  
  
main_dataframe.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#        Gene  GSM2932807  GSM2932808  GSM2932809  GSM2932810  GSM2932811  \
# 0        5S      3.6387     1.71650      1.5406     0.01000     0.01000
# 1         5      0.0100     0.01000      0.0100     0.01000     0.01000
# 2       7SK      0.0100     0.92919      0.0100     0.35525     0.01000
# 3  A1BG-AS1      1.2498     0.98933      0.6026     0.60026     0.41022
# 4      A1BG      3.2298     7.34170      5.2408     2.55530     1.62650
#
#    GSM2932812  GSM2932813  GSM2932814  GSM2932815  ...  GSM2933023  \
# 0     0.01000     2.26220      4.2801     5.64640  ...      7.4763
# 1     0.01000     0.01000      0.0100     0.01000  ...      0.0100
# 2     0.01000     0.01000      0.0100     0.01000  ...      0.0100
# ...

# %%
#Make 'Gene' column the new index column
main_dataframe.set_index('Gene', inplace=True)
main_dataframe.head()
# Out:
#           GSM2932807  GSM2932808  GSM2932809  GSM2932810  GSM2932811  \
# Gene
# 5S            3.6387     1.71650      1.5406     0.01000     0.01000
# 5             0.0100     0.01000      0.0100     0.01000     0.01000
# 7SK           0.0100     0.92919      0.0100     0.35525     0.01000
# A1BG-AS1      1.2498     0.98933      0.6026     0.60026     0.41022
# A1BG          3.2298     7.34170      5.2408     2.55530     1.62650
#
#           GSM2932812  GSM2932813  GSM2932814  GSM2932815  GSM2932816  ...  \
# Gene                                                                  ...
# 5S           0.01000     2.26220      4.2801     5.64640     3.65850  ...
# 5            0.01000     0.01000      0.0100     0.01000     0.01000  ...
# 7SK          0.01000     0.01000      0.0100     0.01000     0.33258  ...
# A1BG-AS1     0.87175     0.42899      0.5787     0.42655     0.52162  ...
# A1BG         2.67920     2.79010      2.7155     2.23050     2.40190  ...
#
# ...

# %%
#Transform table 
main_dataframe_t = main_dataframe.T
main_dataframe_t.head()
# Out:
# Gene            5S     5      7SK  A1BG-AS1    A1BG     A1CF  A2M-AS1  \
# GSM2932807  3.6387  0.01  0.01000   1.24980  3.2298  11.3730  0.28384
# GSM2932808  1.7165  0.01  0.92919   0.98933  7.3417  15.5388  0.13420
# GSM2932809  1.5406  0.01  0.01000   0.60260  5.2408   6.0193  0.37015
# GSM2932810  0.0100  0.01  0.35525   0.60026  2.5553  19.3306  0.42019
# GSM2932811  0.0100  0.01  0.01000   0.41022  1.6265  12.2060  0.21807
#
# Gene        A2ML1-AS1  A2ML1-AS2     A2ML1  ...  snoU2-30   snoU2  snoU83B  \
# GSM2932807       0.01    0.01000  0.113000  ...      0.01  0.0100   1.4326
# GSM2932808       0.01    0.01000  0.010000  ...      0.01  0.0100   0.0100
# GSM2932809       0.01    0.30727  0.043795  ...      0.01  1.6738   0.0100
# GSM2932810       0.01    0.01000  0.011602  ...      0.01  0.0100   0.0100
# GSM2932811       0.01    0.01000  0.011105  ...      0.01  0.0100   0.0100
#
# Gene        snoZ196  snoZ278  snoZ40  snoZ6  snosnR66      uc  yR211F11.2
# ...

# %%
main_dataframe_t.shape
# Out:
# (226, 58524)

# %%
#upload the second table
table_df = pd.read_csv('SraRunTable.txt')

# %%
table_df['Diagnosis'].unique
# Out:
# <bound method Series.unique of 0                 Control
# 1                 Control
# 2                 Control
# 3                 Control
# 4                 Control
#               ...
# 221    Ulcerative Colitis
# 222    Ulcerative Colitis
# 223    Ulcerative Colitis
# 224    Ulcerative Colitis
# 225    Ulcerative Colitis
# Name: Diagnosis, Length: 226, dtype: object>

# %%
table_df.columns
# Out:
# Index(['Run', 'Age_at_diagnosis', 'Assay Type', 'AvgSpotLen', 'Bases',
#        'BioProject', 'BioSample', 'Bytes', 'Center Name', 'Consent',
#        'DATASTORE filetype', 'DATASTORE provider', 'DATASTORE region',
#        'Diagnosis', 'Experiment', 'GEO_Accession (exp)', 'initial_treatment',
#        'Instrument', 'LibraryLayout', 'LibrarySelection', 'LibrarySource',
#        'Organism', 'Platform', 'PUCAI', 'ReleaseDate', 'Sample Name', 'sex',
#        'source_name', 'SRA Study', 'tissue', 'total_mayo_score',
#        'week_4_remission', 'histology_severity_score', 'week_4_calprotectin',
#        'baseline_calprotectin'],
#       dtype='object')

# %%
#Make 'Sample Name' column the index column to match the index of the previous table
table_df.set_index('Sample Name', inplace=True)

# %%
table_df.head()
# Out:
#                     Run  Age_at_diagnosis Assay Type  AvgSpotLen       Bases  \
# Sample Name
# GSM2932807   SRR6467548                16    RNA-Seq         150  5377705200
# GSM2932808   SRR6467549                11    RNA-Seq         150  5275216650
# GSM2932809   SRR6467550                17    RNA-Seq         150  5903990700
# GSM2932810   SRR6467551                 8    RNA-Seq         150  4313372250
# GSM2932811   SRR6467552                17    RNA-Seq         150  4928637150
#
#               BioProject     BioSample       Bytes Center Name Consent  ...  \
# Sample Name                                                             ...
# GSM2932807   PRJNA429769  SAMN08359027  3201841363         GEO  public  ...
# GSM2932808   PRJNA429769  SAMN08359028  2502810829         GEO  public  ...
# GSM2932809   PRJNA429769  SAMN08359026  2746732954         GEO  public  ...
# GSM2932810   PRJNA429769  SAMN08359025  1856472093         GEO  public  ...
# ...

# %%
#Concat the two tables by joining shared index rows
new_df = pd.concat([table_df, main_dataframe_t], axis = 1, join='inner')

# %%
new_df.shape
# Out:
# (226, 58558)

# %%
new_df.head()
# Out:
#                    Run  Age_at_diagnosis Assay Type  AvgSpotLen       Bases  \
# GSM2932807  SRR6467548                16    RNA-Seq         150  5377705200
# GSM2932808  SRR6467549                11    RNA-Seq         150  5275216650
# GSM2932809  SRR6467550                17    RNA-Seq         150  5903990700
# GSM2932810  SRR6467551                 8    RNA-Seq         150  4313372250
# GSM2932811  SRR6467552                17    RNA-Seq         150  4928637150
#
#              BioProject     BioSample       Bytes Center Name Consent  ...  \
# GSM2932807  PRJNA429769  SAMN08359027  3201841363         GEO  public  ...
# GSM2932808  PRJNA429769  SAMN08359028  2502810829         GEO  public  ...
# GSM2932809  PRJNA429769  SAMN08359026  2746732954         GEO  public  ...
# GSM2932810  PRJNA429769  SAMN08359025  1856472093         GEO  public  ...
# GSM2932811  PRJNA429769  SAMN08359024  2269507890         GEO  public  ...
#
# ...

# %%
new_df1 = new_df.copy()

# %%
  
# Remove irrelevant columns
new_df_dropped = new_df1.drop(['Bytes', 'Run','BioProject','AvgSpotLen','Assay Type','BioProject','BioSample','Center Name','Consent','ReleaseDate','SRA Study','DATASTORE filetype','DATASTORE provider','DATASTORE region','Instrument','Organism','LibrarySource','LibrarySelection','Experiment','LibraryLayout','Platform','GEO_Accession (exp)'], axis = 1)

# %%
new_df_dropped.head()
# Out:
#             Age_at_diagnosis       Bases Diagnosis initial_treatment  PUCAI  \
# GSM2932807                16  5377705200   Control               NaN    NaN
# GSM2932808                11  5275216650   Control               NaN    NaN
# GSM2932809                17  5903990700   Control               NaN    NaN
# GSM2932810                 8  4313372250   Control               NaN    NaN
# GSM2932811                17  4928637150   Control               NaN    NaN
#
#                sex                                        source_name  \
# GSM2932807  female  Rectal mucosal biopsy from Ctl Female age 16 a...
# GSM2932808  female  Rectal mucosal biopsy from Ctl Female age 11 a...
# GSM2932809  female  Rectal mucosal biopsy from Ctl Female age 17 a...
# GSM2932810  female  Rectal mucosal biopsy from Ctl Female age 8 at...
# GSM2932811  female  Rectal mucosal biopsy from Ctl Female age 17 a...
#
#                            tissue  total_mayo_score week_4_remission  ...  \
# ...

# %%
new_df_dropped.to_csv('Colitis_table.csv')

# %% [markdown]
# ## RISK dataset

# %%
risk_table_df = pd.read_csv('Galaxy2-[Convert_tabular_to_CSV_on_data_1].csv')

# %%
risk_table_df
# Out:
#             Run Assay Type  AvgSpotLen       Bases   BioProject  \
# 0    SRR7632756    RNA-Seq          75  1172311575  PRJNA483949
# 1    SRR7632757    RNA-Seq          50   577579500  PRJNA483949
# 2    SRR7632758    RNA-Seq          75  1334638875  PRJNA483949
# 3    SRR7632759    RNA-Seq          75   903872100  PRJNA483949
# 4    SRR7632760    RNA-Seq          75  1122933900  PRJNA483949
# ..          ...        ...         ...         ...          ...
# 185  SRR7632941    RNA-Seq          50   899676000  PRJNA483949
# 186  SRR7632942    RNA-Seq          50   501153100  PRJNA483949
# 187  SRR7632943    RNA-Seq          50  1928556600  PRJNA483949
# 188  SRR7632944    RNA-Seq          50   826146900  PRJNA483949
# 189  SRR7632945    RNA-Seq          50  2404356500  PRJNA483949
#
#     biopsy_location     BioSample       Bytes Center Name Consent  ...  \
# 0            rectal  SAMN09754072   740576203         GEO  public  ...
# ...

# %%
#Make 'Sample Name' column the index column to match the index of the previous table
risk_table_df.set_index('Sample Name', inplace=True)

# %%
risk_table_df.head()
# Out:
#                     Run Assay Type  AvgSpotLen       Bases   BioProject  \
# Sample Name
# GSM3316656   SRR7632756    RNA-Seq          75  1172311575  PRJNA483949
# GSM3316657   SRR7632757    RNA-Seq          50   577579500  PRJNA483949
# GSM3316658   SRR7632758    RNA-Seq          75  1334638875  PRJNA483949
# GSM3316659   SRR7632759    RNA-Seq          75   903872100  PRJNA483949
# GSM3316660   SRR7632760    RNA-Seq          75  1122933900  PRJNA483949
#
#             biopsy_location     BioSample      Bytes Center Name Consent  ...  \
# Sample Name                                                               ...
# GSM3316656           rectal  SAMN09754072  740576203         GEO  public  ...
# GSM3316657           rectal  SAMN09754071  414816623         GEO  public  ...
# GSM3316658           rectal  SAMN09754070  859351625         GEO  public  ...
# GSM3316659           rectal  SAMN09754069  572907923         GEO  public  ...
# ...

# %%
txt_list = ['GSM3316701_05-116-R.txt', 'GSM3316834_13-051-R.txt', 'GSM3316844_29-011-R.txt', 'GSM3316699_05-077-R.txt', 'GSM3316717_11-002-R.txt', 'GSM3316750_03-075-R.txt', 'GSM3316681_18-012-R.txt', 'GSM3316658_03-143-R.txt', 'GSM3316757_05-100-R.txt', 'GSM3316718_11-009-R.txt', 'GSM3316665_06-053-R.txt', 'GSM3316732_16-005-R.txt', 'GSM3316740_23-016-R.txt', 'GSM3316760_05-127-R.txt', 'GSM3316761_06-050-R.txt', 'GSM3316743_27-024-R.txt', 'GSM3316666_07-031-R.txt', 'GSM3316840_15-008-R.txt', 'GSM3316663_05-133-R.txt', 'GSM3316804_03-047-R.txt', 'GSM3316768_06-091-R.txt', 'GSM3316811_05-112-R.txt', 'GSM3316814_06-070-R.txt', 'GSM3316766_06-078-R.txt', 'GSM3316796_24-018-R.txt', 'GSM3316842_27-020-R.txt', 'GSM3316820_08-008-R.txt', 'GSM3316711_08-015-R.txt', 'GSM3316704_06-062-R.txt', 'GSM3316753_03-115-R.txt', 'GSM3316705_06-065-R.txt', 'GSM3316812_05-138-R.txt', 'GSM3316719_11-019-R.txt', 'GSM3316769
M3316788_21-020-R.txt', 'GSM3316823_08-021-R.txt', 'GSM3316678_15-011-R.txt', 'GSM3316700_05-082-R.txt', 'GSM3316758_05-102-R.txt', 'GSM3316736_20-013-R.txt', 'GSM3316829_10-043-R.txt', 'GSM3316835_13-084-R.txt', 'GSM3316756_05-094-R.txt', 'GSM3316841_23-006-R.txt', 'GSM3316845_29-020-R.txt', 'GSM3316689_03-106-R.txt', 'GSM3316822_08-018-R.txt', 'GSM3316675_14-037-R.txt', 'GSM3316708_06-075-R.txt', 'GSM3316716_09-042-R.txt', 'GSM3316661_04-123-R.txt', 'GSM3316698_05-072-R.txt', 'GSM3316837_13-125-R.txt', 'GSM3316720_12-028-R.txt', 'GSM3316778_08-026-R.txt', 'GSM3316763_06-063-R.txt', 'GSM3316818_07-053-R.txt', 'GSM3316836_13-086-R.txt', 'GSM3316798_27-002-R.txt', 'GSM3316826_09-054-R.txt', 'GSM3316739_22-039-R.txt', 'GSM3316832_11-062-R.txt', 'GSM3316786_17-003-R.txt', 'GSM3316828_09-067-R.txt', 'GSM3316780_08-063-R.txt', 'GSM3316702_06-016-R.txt', 'GSM3316821_08-017-R.txt', 'GSM3316799_27-005-R.txt', 'GSM3316686_27-008-R.txt', 'GSM3316677_14-042-R.txt', 'GSM3316772_07-051-R.txt', 'GSM3316684_20-006-R.txt', 'GSM3316737_21-005-R.txt', 'GSM3316707_06-072-R.txt', 'GSM3316783_11-033-R.txt', 'GSM3316759_05-108-R.txt', 'GSM3316751_03-076-R.txt', 'GSM3316744_27-041-R.txt', 'GSM3316672_13-064-R.txt', 'GSM3316742_27-012-R.txt', 'GSM3316676_14-038-R.txt', 'GSM3316831_11-060-R.txt', 'GSM3316729_14-035-R.txt', 'GSM3316673_14-009-R.txt', 'GSM3316714_09-020-R.txt', 'GSM3316843_27-028-R.txt', 'GSM3316806_05-073-R.txt', 'GSM3316724_13-170-R.txt', 'GSM3316669_09-014-R.txt', 'GSM3316764_06-064-R.txt', 'GSM3316782_11-028-R.txt', 'GSM3316838_13-135-R.txt', 'GSM3316667_08-031-R.txt', 'GSM3316746_29-018-R.txt', 'GSM3316721_13-055-R.txt', 'GSM3316830_11-032-R.txt', 'GSM3316787_21-018-R.txt', 'GSM3316817_07-049-R.txt', 'GSM3316767_06-082-R.txt', 'GSM3316687_29-010-R.txt', 'GSM3316792_24-009-R.txt', 'GSM3316725_14-003-R.txt', 'GSM3316803_01-064-R.txt', 'GSM3316706_06-069-R.txt', 'GSM3316671_11-014-R.txt']
txt_list.sort(reverse = False)

# %%
new_names = []

for i in txt_list:
  i = i.split('_')[0]
  new_names.append(i)

for i,j in zip(txt_list, new_names):
  j = pd.read_csv(i)

# %%
main_dataframe = pd.DataFrame(pd.read_table(txt_list[0]))
sf = pd.Series()
for i in range(0,len(txt_list)):
    data = pd.read_table(txt_list[i])
    if i == 0:
     df = pd.DataFrame(data)
     df = df.rename(columns={df.columns[1]: txt_list[i]}) #Rename value column to filename
     main_dataframe = df
     for col in main_dataframe.columns:
       name = col.split('_')[0]
       main_dataframe.rename(columns = {col : name}, inplace = True) #Leave onle the string that somes before the _ as acolumn name
    else:
     df = pd.DataFrame(data.iloc[:,1])
     df = df.rename(columns={df.columns[0]: txt_list[i]})
     main_dataframe = pd.concat([main_dataframe,df], axis = 1) # add only the value column (without the gene name column) to the dataframe
     for col in main_dataframe.columns:
       name = col.split('_')[0]
       main_dataframe.rename(columns = {col : name}, inplace = True)
  
  
main_dataframe.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#      Symbol  GSM3316656  GSM3316657  GSM3316658  GSM3316659  GSM3316660  \
# 0        5S      0.0100      0.0100      0.0100      0.0100      0.0100
# 1         5      0.0100      0.0100      0.0100      0.0100      0.0100
# 2       7SK      0.0100      0.0100      0.0100      0.0100      0.0100
# 3  A1BG-AS1      2.9849      1.7069      1.6019      1.8899      1.1757
# 4      A1BG      5.5665      5.2550      3.0674      5.1529      4.6359
#
#    GSM3316661  GSM3316662  GSM3316663  GSM3316664  ...  GSM3316836  \
# 0      0.0100     0.01000      0.0100      0.0100  ...      0.0100
# 1      0.0100     0.01000      0.0100      0.0100  ...      0.0100
# 2      0.0100     0.01000      0.0100      0.0100  ...      0.0100
# ...

# %%
#Make 'Gene' column the new index column
main_dataframe.set_index('Symbol', inplace=True)
main_dataframe.head()
# Out:
#           GSM3316656  GSM3316657  GSM3316658  GSM3316659  GSM3316660  \
# Symbol
# 5S            0.0100      0.0100      0.0100      0.0100      0.0100
# 5             0.0100      0.0100      0.0100      0.0100      0.0100
# 7SK           0.0100      0.0100      0.0100      0.0100      0.0100
# A1BG-AS1      2.9849      1.7069      1.6019      1.8899      1.1757
# A1BG          5.5665      5.2550      3.0674      5.1529      4.6359
#
#           GSM3316661  GSM3316662  GSM3316663  GSM3316664  GSM3316665  ...  \
# Symbol                                                                ...
# 5S            0.0100     0.01000      0.0100      0.0100      0.0100  ...
# 5             0.0100     0.01000      0.0100      0.0100      0.0100  ...
# 7SK           0.0100     0.01000      0.0100      0.0100      0.0100  ...
# A1BG-AS1      1.9852     0.80658      1.4188      3.3132      2.3131  ...
# A1BG          4.7868     9.36270      6.6647     10.2437      4.5610  ...
#
# ...

# %%
#a way to set index by column index : df.set_index(list(df.columns[[0,2]]))

# %%
main_dataframe.to_csv('RISK_genes.csv')

# %%
#Transform table 
main_dataframe_t = main_dataframe.T
main_dataframe_t.head()
# Out:
# Symbol        5S     5   7SK  A1BG-AS1    A1BG    A1CF  A2M-AS1  A2ML1-AS1  \
# GSM3316656  0.01  0.01  0.01    2.9849  5.5665  2.7558  0.66781       0.01
# GSM3316657  0.01  0.01  0.01    1.7069  5.2550  6.8711  0.47938       0.01
# GSM3316658  0.01  0.01  0.01    1.6019  3.0674  8.1149  0.44036       0.01
# GSM3316659  0.01  0.01  0.01    1.8899  5.1529  4.1582  0.18452       0.01
# GSM3316660  0.01  0.01  0.01    1.1757  4.6359  7.5521  0.61863       0.01
#
# Symbol      A2ML1-AS2     A2ML1  ...  snoU2-30  snoU2  snoU83B  snoZ196  \
# GSM3316656       0.01  0.371800  ...      0.01   0.01     0.01     0.01
# GSM3316657       0.01  0.153400  ...      0.01   0.01     0.01     0.01
# GSM3316658       0.01  0.189810  ...      0.01   0.01     0.01     0.01
# GSM3316659       0.01  0.070184  ...      0.01   0.01     0.01     0.01
# GSM3316660       0.01  0.019571  ...      0.01   0.01     0.01     0.01
#
# Symbol      snoZ278  snoZ40  snoZ6  snosnR66       uc  yR211F11.2
# ...

# %%
#Concat the two tables by joining shared index rows
new_df = pd.concat([risk_table_df, main_dataframe_t], axis = 1, join='inner')

# %%
new_df
# Out:
#                    Run Assay Type  AvgSpotLen       Bases   BioProject  \
# GSM3316656  SRR7632756    RNA-Seq          75  1172311575  PRJNA483949
# GSM3316657  SRR7632757    RNA-Seq          50   577579500  PRJNA483949
# GSM3316658  SRR7632758    RNA-Seq          75  1334638875  PRJNA483949
# GSM3316659  SRR7632759    RNA-Seq          75   903872100  PRJNA483949
# GSM3316660  SRR7632760    RNA-Seq          75  1122933900  PRJNA483949
# ...                ...        ...         ...         ...          ...
# GSM3316841  SRR7632941    RNA-Seq          50   899676000  PRJNA483949
# GSM3316842  SRR7632942    RNA-Seq          50   501153100  PRJNA483949
# GSM3316843  SRR7632943    RNA-Seq          50  1928556600  PRJNA483949
# GSM3316844  SRR7632944    RNA-Seq          50   826146900  PRJNA483949
# GSM3316845  SRR7632945    RNA-Seq          50  2404356500  PRJNA483949
#
#            biopsy_location     BioSample       Bytes Center Name Consent  ...  \
# ...

# %%
new_df.to_csv('RISK_table_full.csv')

# %%
table_risk = new_df.copy()

# %%
risk_table_df.columns
# Out:
# Index(['Run', 'Assay Type', 'AvgSpotLen', 'Bases', 'BioProject',
#        'biopsy_location', 'BioSample', 'Bytes', 'Center Name', 'Consent',
#        'DATASTORE filetype', 'DATASTORE provider', 'DATASTORE region',
#        'Diagnosis', 'disease_subtype', 'Experiment', 'GEO_Accession (exp)',
#        'Instrument', 'LibraryLayout', 'LibrarySelection', 'LibrarySource',
#        'Location', 'Organism', 'Platform', 'population', 'ReleaseDate',
#        'source_name', 'SRA Study', 'tissue'],
#       dtype='object')

# %%
columns_todropp = ['Bytes','Location','population','tissue','source_name','disease_subtype','Experiment','biopsy_location','Bases', 'Run','AvgSpotLen','Assay Type','BioProject','BioSample','Center Name','Consent','ReleaseDate','SRA Study','DATASTORE filetype','DATASTORE provider','DATASTORE region','Instrument','Organism','LibrarySource','LibrarySelection','Experiment','LibraryLayout','Platform','GEO_Accession (exp)']

# %%
# Remove irrelevant columns
table_risk_dropped = table_risk.drop(columns_todropp, axis = 1)

# %%
table_risk_dropped
# Out:
#            Diagnosis    5S     5      7SK  A1BG-AS1     A1BG     A1CF  \
# GSM3316656        CD  0.01  0.01  0.01000    2.9849   5.5665   2.7558
# GSM3316657        CD  0.01  0.01  0.01000    1.7069   5.2550   6.8711
# GSM3316658        CD  0.01  0.01  0.01000    1.6019   3.0674   8.1149
# GSM3316659        CD  0.01  0.01  0.01000    1.8899   5.1529   4.1582
# GSM3316660        CD  0.01  0.01  0.01000    1.1757   4.6359   7.5521
# ...              ...   ...   ...      ...       ...      ...      ...
# GSM3316841        UC  0.01  0.01  0.45446    1.8118  14.5272   4.0182
# GSM3316842        UC  0.01  0.01  0.01000    4.9318  13.4168   1.0260
# GSM3316843        UC  0.01  0.01  0.01000    2.7266   7.2825   4.6098
# GSM3316844        UC  0.01  0.01  0.01000    1.3287   3.6846  19.8337
# GSM3316845        UC  0.01  0.01  0.01000    1.9345   6.1163  10.5848
#
#             A2M-AS1  A2ML1-AS1  A2ML1-AS2  ...  snoU2-30  snoU2  snoU83B  \
# ...

# %%
table_risk_dropped.to_csv('RISK_table_dropped.csv')

# %% [markdown]
# # Merge PROTECT RISK

# %%
#upload full PROTECT table
protect_table = pd.read_csv('Colitis_table.csv', index_col=0)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4,10,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
protect_table.columns
# Out:
# Index(['Age_at_diagnosis', 'Bases', 'Diagnosis', 'initial_treatment', 'PUCAI',
#        'sex', 'source_name', 'tissue', 'total_mayo_score', 'week_4_remission',
#        ...
#        'snoU2-30', 'snoU2', 'snoU83B', 'snoZ196', 'snoZ278', 'snoZ40', 'snoZ6',
#        'snosnR66', 'uc', 'yR211F11.2'],
#       dtype='object', length=58537)

# %%
columns_todropp2 = ['sex','PUCAI','initial_treatment','total_mayo_score','week_4_remission','histology_severity_score','week_4_calprotectin','baseline_calprotectin','Bytes','Location','population','tissue','source_name','disease_subtype','Experiment','biopsy_location','Bases', 'Run','AvgSpotLen','Assay Type','BioProject','BioSample','Center Name','Consent','ReleaseDate','SRA Study','DATASTORE filetype','DATASTORE provider','DATASTORE region','Instrument','Organism','LibrarySource','LibrarySelection','Experiment','LibraryLayout','Platform','GEO_Accession (exp)', 'Age_at_diagnosis']

# %%
#drop columns except for genes and diagnosis
protect_table_dropped = protect_table.copy()
for i in protect_table_dropped.columns:
  if i in columns_todropp2:
    protect_table_dropped = protect_table_dropped.drop([i], axis = 1)
protect_table_dropped
# Out:
#                      Diagnosis       5S     5      7SK  A1BG-AS1    A1BG  \
# GSM2932807             Control   3.6387  0.01  0.01000   1.24980  3.2298
# GSM2932808             Control   1.7165  0.01  0.92919   0.98933  7.3417
# GSM2932809             Control   1.5406  0.01  0.01000   0.60260  5.2408
# GSM2932810             Control   0.0100  0.01  0.35525   0.60026  2.5553
# GSM2932811             Control   0.0100  0.01  0.01000   0.41022  1.6265
# ...                        ...      ...   ...      ...       ...     ...
# GSM2933028  Ulcerative Colitis   2.8788  0.01  0.01000   1.58760  5.5376
# GSM2933029  Ulcerative Colitis  10.1511  0.01  0.44722   0.78939  2.8797
# GSM2933030  Ulcerative Colitis   3.4405  0.01  0.01000   1.66600  6.5167
# GSM2933031  Ulcerative Colitis   4.5914  0.01  0.24876   1.38210  3.7193
# GSM2933032  Ulcerative Colitis   2.2099  0.01  0.01000   1.23470  3.0866
#
#                A1CF  A2M-AS1  A2ML1-AS1  A2ML1-AS2  ...  snoU2-30   snoU2  \
# ...

# %%
#replace "Ulcerative Colitis" in diagnosis  to UC

protect_table_dropped.replace(to_replace = "Ulcerative Colitis", value = "UC", inplace = True)

# %%
protect_table_dropped['Diagnosis'].unique
# Out:
# <bound method Series.unique of GSM2932807    Control
# GSM2932808    Control
# GSM2932809    Control
# GSM2932810    Control
# GSM2932811    Control
#                ...
# GSM2933028         UC
# GSM2933029         UC
# GSM2933030         UC
# GSM2933031         UC
# GSM2933032         UC
# Name: Diagnosis, Length: 226, dtype: object>

# %%
protect_table_dropped.to_csv('PROTECT_RNA.csv')

# %%
#Merge both tables

protect_risk_rna = table_risk_dropped.append(protect_table_dropped, ignore_index = False)

# %%
protect_risk_rna
# Out:
#            Diagnosis       5S     5      7SK  A1BG-AS1    A1BG     A1CF  \
# GSM3316656        CD   0.0100  0.01  0.01000   2.98490  5.5665   2.7558
# GSM3316657        CD   0.0100  0.01  0.01000   1.70690  5.2550   6.8711
# GSM3316658        CD   0.0100  0.01  0.01000   1.60190  3.0674   8.1149
# GSM3316659        CD   0.0100  0.01  0.01000   1.88990  5.1529   4.1582
# GSM3316660        CD   0.0100  0.01  0.01000   1.17570  4.6359   7.5521
# ...              ...      ...   ...      ...       ...     ...      ...
# GSM2933028        UC   2.8788  0.01  0.01000   1.58760  5.5376   9.0400
# GSM2933029        UC  10.1511  0.01  0.44722   0.78939  2.8797  15.3547
# GSM2933030        UC   3.4405  0.01  0.01000   1.66600  6.5167   8.2175
# GSM2933031        UC   4.5914  0.01  0.24876   1.38210  3.7193   7.8746
# GSM2933032        UC   2.2099  0.01  0.01000   1.23470  3.0866   6.8312
#
#             A2M-AS1  A2ML1-AS1  A2ML1-AS2  ...  snoU2-30  snoU2  snoU83B  \
# ...

# %%
protect_risk_rna.to_csv('PROTECT_RISK_rna_fuul.csv')

# %%
protect_risk_rna['Diagnosis'].unique()
# Out:
# array(['CD', 'Control', 'UC'], dtype=object)

# %%
#remove cd rows
not_US_ctl = protect_risk_rna[protect_risk_rna['Diagnosis'] == 'CD' ].index
  
protect_risk_rna_US = protect_risk_rna.copy()
# drop these row indexes
# from dataFrame
protect_risk_rna_US.drop(not_US_ctl, inplace = True)
  
protect_risk_rna_US
# Out:
#            Diagnosis       5S     5      7SK  A1BG-AS1    A1BG     A1CF  \
# GSM3316748   Control   0.0100  0.01  0.01000   2.65760  5.8870   8.5168
# GSM3316749   Control   0.0100  0.01  0.01000   1.41470  6.6428   8.5053
# GSM3316750   Control   0.0100  0.01  0.01000   1.10300  4.0985   8.0321
# GSM3316751   Control   0.0100  0.01  0.01000   1.20420  5.6552   7.3897
# GSM3316752   Control   0.0100  0.01  0.01000   2.87090  6.6788   8.6186
# ...              ...      ...   ...      ...       ...     ...      ...
# GSM2933028        UC   2.8788  0.01  0.01000   1.58760  5.5376   9.0400
# GSM2933029        UC  10.1511  0.01  0.44722   0.78939  2.8797  15.3547
# GSM2933030        UC   3.4405  0.01  0.01000   1.66600  6.5167   8.2175
# GSM2933031        UC   4.5914  0.01  0.24876   1.38210  3.7193   7.8746
# GSM2933032        UC   2.2099  0.01  0.01000   1.23470  3.0866   6.8312
#
#             A2M-AS1  A2ML1-AS1  A2ML1-AS2  ...  snoU2-30  snoU2  snoU83B  \
# ...

# %%
protect_risk_rna_US.Diagnosis.unique()
# Out:
# array(['Control', 'UC'], dtype=object)

# %%
protect_risk_rna_US.Diagnosis.value_counts( )
# Out:
# UC         249
# Control     75
# Name: Diagnosis, dtype: int64

# %%
protect_risk_rna_US.to_csv('PROTECT_RISK_only_RNA.csv')

# %% [markdown]
# Preparing RISK, PROTECT DEGs df prior to z-score normalization

# %%
risk_degs = pd.read_csv('RISK and PROTECT shared DEGs.txt', index_col=0)
df_not_nrm = pd.read_csv('PROTECT_RISK_only_RNA.csv', index_col=0)

# %%
df_not_nrm.head()

# %%
degs_list2 = risk_degs.index.to_list()

# %%
df3_d = df_not_nrm.copy()

# %%
df3_d.iloc[:,0]

# %%
df3_degs = df3_d.iloc[:,0:1]

# %%
#dff = pd.DataFrame()
for i in df_not_nrm.columns:
  if i in degs_list2:
    
    #dff = pd.concat([dff,df2[i]], axis = 1, inplace = True)
    df3_degs[i] = df_not_nrm[i]

df3_degs

# %%
df3_degs.to_csv('PROTECT_and_RISK_shared_DEGs_NOT NORM.csv')

# %%
df_test = df3_degs.copy()

# %%
df_test.describe()
# Out:
#             AAMDC        ABAT      ABCA12       ABCB1       ABCC1       ABCG2  \
# count  324.000000  324.000000  324.000000  324.000000  324.000000  324.000000
# mean    18.481036    3.686130    1.460926   14.131209    9.399889    8.487860
# std     10.509028    1.930181    1.611165   15.173998    4.423135   13.000225
# min      5.340900    0.767070    0.010000    0.846780    1.275200    0.200300
# 25%     12.271325    2.435200    0.109912    4.014650    5.760975    1.082050
# 50%     15.192550    3.199000    0.967935    7.028650    9.534050    2.640650
# 75%     21.108275    4.220400    2.244250   18.696525   12.588700    9.167875
# max     84.242900   12.412200    8.625800   81.820200   24.768600   67.012800
#
#            ABLIM2  AC013461.1   AC234582.1       ACAA1  ...      ZNF575  \
# count  324.000000  324.000000   324.000000  324.000000  ...  324.000000
# mean     3.219015    6.710549   679.945166   59.192552  ...    3.234691
# ...

# %%
df_test.head()
# Out:
#            Diagnosis    AAMDC    ABAT    ABCA12    ABCB1    ABCC1    ABCG2  \
# GSM3316748   Control  25.9348  5.5414  0.039268  36.8688   5.8691  22.0679
# GSM3316749   Control  11.6939  3.7807  0.289900  18.9955   9.7232   4.9927
# GSM3316750   Control  28.4807  5.9662  0.010000  38.3700   6.2720  45.4189
# GSM3316751   Control  35.8430  4.2965  0.010081  35.1791   4.7454  14.0527
# GSM3316752   Control  30.4372  5.7828  0.010000  81.8202  11.7178  26.8624
#
#             ABLIM2  AC013461.1  AC234582.1  ...  ZNF575    ZNF57  ZNF613  \
# GSM3316748  5.1852      4.7936    100.4090  ...  5.1506   6.7886  5.3642
# GSM3316749  1.7404      6.8132    188.9640  ...  8.1902   6.2496  7.4671
# GSM3316750  2.4148      2.6355     92.5353  ...  9.1893  10.8217  3.3373
# GSM3316751  5.9738      2.0259    185.8320  ...  8.3106   6.6119  5.7008
# GSM3316752  4.3558      6.7774    114.3290  ...  4.6946   7.6748  4.5044
#
#              ZNF69   ZNF703  ZNF704  ZNF844    ZNF91   ZNRF3  ZSWIM5
# ...
