# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('PROTECT_and_RISK_shared_DEGs_NOT NORM.csv', index_col=0)

# %%
df1 = df.copy()

# %%
df1.head()
# Out:
#            Diagnosis    AAMDC    ABAT    ABCA12    ABCB1    ABCC1    ABCG2  \
# GSM3316748   Control  25.9348  5.5414  0.039268  36.8688   5.8691  22.0679
# GSM3316749   Control  11.6939  3.7807  0.289900  18.9955   9.7232   4.9927
# GSM3316750   Control  28.4807  5.9662  0.010000  38.3700   6.2720  45.4189
# GSM3316751   Control  35.8430  4.2965  0.010081  35.1791   4.7454  14.0527
# GSM3316752   Control  30.4372  5.7828  0.010000  81.8202  11.7178  26.8624
#
#             ABLIM2  AC013461.1  AC234582.1  ...  ZNF575    ZNF57  ZNF613  \
# GSM3316748  5.1852      4.7936    100.4090  ...  5.1506   6.7886  5.3642
# GSM3316749  1.7404      6.8132    188.9640  ...  8.1902   6.2496  7.4671
# GSM3316750  2.4148      2.6355     92.5353  ...  9.1893  10.8217  3.3373
# GSM3316751  5.9738      2.0259    185.8320  ...  8.3106   6.6119  5.7008
# GSM3316752  4.3558      6.7774    114.3290  ...  4.6946   7.6748  4.5044
#
#              ZNF69   ZNF703  ZNF704  ZNF844    ZNF91   ZNRF3  ZSWIM5
# GSM3316748  7.1065  38.7633  4.5095  3.7331  20.2813  3.3339  3.6266
# GSM3316749  3.8288  20.2415  4.0327  2.4122  13.5649  2.5927  2.2582
# GSM3316750  4.9504  32.2447  2.9052  2.7927  17.5972  2.0049  3.2104
# GSM3316751  5.3747  34.0843  3.3492  3.1923  13.9003  1.7972  2.8750
# GSM3316752  6.7213  33.9893  4.0935  5.3238  22.7351  2.9283  2.4813
#
# [5 rows x 1883 columns]

# %% [markdown]
# # *EDA*

# %% [markdown]
# ## Raw data

# %%
df1.describe()
# Out:
#             AAMDC        ABAT      ABCA12       ABCB1       ABCC1       ABCG2  \
# count  324.000000  324.000000  324.000000  324.000000  324.000000  324.000000
# mean    18.481036    3.686130    1.460926   14.131209    9.399889    8.487860
# std     10.509028    1.930181    1.611165   15.173998    4.423135   13.000225
# min      5.340900    0.767070    0.010000    0.846780    1.275200    0.200300
# 25%     12.271325    2.435200    0.109912    4.014650    5.760975    1.082050
# 50%     15.192550    3.199000    0.967935    7.028650    9.534050    2.640650
# 75%     21.108275    4.220400    2.244250   18.696525   12.588700    9.167875
# max     84.242900   12.412200    8.625800   81.820200   24.768600   67.012800
#
#            ABLIM2  AC013461.1   AC234582.1       ACAA1  ...      ZNF575  \
# count  324.000000  324.000000   324.000000  324.000000  ...  324.000000
# mean     3.219015    6.710549   679.945166   59.192552  ...    3.234691
# std      1.702311    2.804100   512.190495   23.807293  ...    1.966933
# min      0.676770    0.763870     4.060500   21.118300  ...    0.706300
# 25%      2.153400    4.659975   256.253750   42.909825  ...    1.806400
# 50%      2.712100    6.763500   583.526450   51.182550  ...    2.613200
# 75%      3.765825    8.547925   978.399725   68.982350  ...    4.194175
# max     10.775600   15.801700  2713.060300  151.812400  ...   10.794800
#
#             ZNF57      ZNF613       ZNF69      ZNF703      ZNF704      ZNF844  \
# count  324.000000  324.000000  324.000000  324.000000  324.000000  324.000000
# mean     4.813666    3.258993    5.111352   17.712241    3.080993    2.442990
# std      2.081730    1.611000    2.204151    7.665073    1.817260    1.169766
# min      1.069800    0.785520    0.805130    2.792200    0.232310    0.519280
# 25%      3.256200    2.174800    3.580975   12.601525    1.754975    1.671225
# 50%      4.473300    2.785950    4.838800   15.894100    2.694550    2.268950
# 75%      6.090225    3.654175    6.491975   20.970450    3.957400    2.897425
# max     11.163100    9.408800   13.347500   51.124500   10.661700    7.409700
#
#             ZNF91       ZNRF3      ZSWIM5
# count  324.000000  324.000000  324.000000
# mean    12.589191    1.543881    2.148078
# std      5.566262    0.698195    1.062918
# min      3.370200    0.275470    0.232790
# 25%      8.815900    1.057325    1.369375
# 50%     11.618300    1.429150    2.046850
# 75%     15.136850    1.916275    2.697650
# max     40.195800    4.058200    6.115900
#
# [8 rows x 1882 columns]

# %%
df1.Diagnosis.unique()
# Out:
# array(['Control', 'UC'], dtype=object)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 324 entries, GSM3316748 to GSM2933032
# Columns: 1883 entries, Diagnosis to ZSWIM5
# dtypes: float64(1882), object(1)
# memory usage: 4.7+ MB

# %%
fig = plt.figure(figsize=(1.7, 4))
ax = fig.gca()


y = df1['Diagnosis'].value_counts()
x= y.index

ax.bar( height= y, width=0.5,
       align='center', color='blue',
       x= x)
plt.xticks(rotation=0,fontsize = 13)
#ax.set_title('')
#ax.set_xlabel('', size = 14)
ax.set_ylabel('Number of cases', size = 16)

#def addlabels(x,y):
for i in range(len(x)):
    plt.text(i, y[i]+1, y[i], ha = 'center', color='black', fontweight='bold', size = 12)
#plt.text(x= lables ,y = valuess,  f'    {valuess}')

plt.savefig("Diagnosis bar plot nums", bbox_inches='tight', transparent = True)

plt.show()

# %% [markdown]
# Data before normalization

# %%
#melt so that all gene values will be in one column
risk_protectT = df1.groupby('Diagnosis').mean().T
risk_protectT
# Out:
# Diagnosis    Control         UC
# AAMDC      30.749472  14.785724
# ABAT        5.600679   3.109459
# ABCA12      0.046757   1.886880
# ABCB1      35.216072   7.780347
# ABCC1       4.780085  10.791396
# ...              ...        ...
# ZNF704      4.453198   2.667678
# ZNF844      3.527839   2.116228
# ZNF91      18.258143  10.881676
# ZNRF3       2.210680   1.343039
# ZSWIM5      3.058273   1.873923
#
# [1882 rows x 2 columns]

# %%
risk_protectT.sort_values(by=['UC'], ascending=False).tail(10)
# Out:
# Diagnosis   Control        UC
# TEX11      1.550377  0.630302
# PROC       2.191048  0.626511
# DPP10      3.149777  0.618004
# LCN15      4.869891  0.617594
# NPY        3.526955  0.607771
# MUC5AC     0.056158  0.602704
# RPL10L     1.903560  0.587643
# BMP3       5.059509  0.556506
# GLRA2      2.773821  0.513052
# PLA2G12B   3.410828  0.512296

# %%
#Generation UP or Down labels for 'UC' group genes
#which expression was timesX2 larger or smaller compared to comtrols

risk_protectTup = risk_protectT.copy()
columnss = ['Control', 'UC']

for row_uc,row_crl in zip(risk_protectTup['UC'],risk_protectTup['Control']):
#for row_uc, row_crl in zip(risk_protectTup[i],risk_protectTup[j]):
    if (row_uc/ 2 ) >= row_crl :
      risk_protectTup['UC'].replace(to_replace = row_uc, value = 'UP',  inplace = True)    
    if row_uc  <=  (row_crl/2):
      risk_protectTup['UC'].replace(to_replace = row_uc, value = 'Down',  inplace = True)

risk_protectTup
# Out:
# Diagnosis    Control         UC
# AAMDC      30.749472       Down
# ABAT        5.600679   3.109459
# ABCA12      0.046757         UP
# ABCB1      35.216072       Down
# ABCC1       4.780085         UP
# ...              ...        ...
# ZNF704      4.453198   2.667678
# ZNF844      3.527839   2.116228
# ZNF91      18.258143  10.881676
# ZNRF3       2.210680   1.343039
# ZSWIM5      3.058273   1.873923
#
# [1882 rows x 2 columns]

# %%
list_up_down = risk_protectTup[risk_protectTup['UC'] == 'UP']
list_up_down
list_down = risk_protectTup[risk_protectTup['UC'] == 'Down']
list_down
list_up_down = list_up_down.append(list_down,  ignore_index = True)
list_up_down
# Out:
# Diagnosis     Control    UC
# 0            0.046757    UP
# 1            4.780085    UP
# 2          234.856481    UP
# 3            0.378779    UP
# 4            0.494051    UP
# ...               ...   ...
# 1140         6.155443  Down
# 1141        14.071693  Down
# 1142       362.904925  Down
# 1143         5.702553  Down
# 1144         5.322275  Down
#
# [1145 rows x 2 columns]

# %%
#Number of up or down-regulated genes in uc patients compared to controls (times 2)

ax = list_up_down['UC'].value_counts().sort_index().plot(kind='barh', fontsize = 14, rot = 0, figsize = (7, 3))
ax.set_xlabel('Number of genes',fontsize = 16)
ax.set_ylabel("Averaged DEGs expression of\n  UC compared to patients", fontsize = 12)
plt.tight_layout()
plt.savefig("DEGs expression bar plot.pdf", tight = True)
plt.show()

# %%
# Average values distribution for 'UC' group

ax = risk_protectT['UC'].plot(kind= 'box', fontsize = 14, figsize = (2,4))
  #ax.set_xlabel(i,fontsize = 18)
ax.set_ylabel("Relative values of averaged genes", fontsize = 16)
plt.tight_layout()
plt.savefig("UC Relative avg values box plot.pdf")
plt.show()

# %%
# Averaged values distribution for 'Control' group

ax = risk_protectT['Control'].plot(kind= 'box', fontsize = 14, figsize = (2,4))
  #ax.set_xlabel(i,fontsize = 18)
ax.set_ylabel("Relative values of averaged genes", fontsize = 16)
plt.tight_layout()
plt.savefig("Control avg Relative values box plot.pdf")
plt.show()

# %%
risk_protectb = df1.copy()
risk_protectb.index= df1['Diagnosis']
risk_protectb.drop('Diagnosis', axis =1, inplace = True)
risk_protectb
# Out:
#              AAMDC    ABAT    ABCA12    ABCB1    ABCC1     ABCG2  ABLIM2  \
# Diagnosis
# Control    25.9348  5.5414  0.039268  36.8688   5.8691  22.06790  5.1852
# Control    11.6939  3.7807  0.289900  18.9955   9.7232   4.99270  1.7404
# Control    28.4807  5.9662  0.010000  38.3700   6.2720  45.41890  2.4148
# Control    35.8430  4.2965  0.010081  35.1791   4.7454  14.05270  5.9738
# Control    30.4372  5.7828  0.010000  81.8202  11.7178  26.86240  4.3558
# ...            ...     ...       ...      ...      ...       ...     ...
# UC         12.8054  3.7931  1.888200   6.3028  11.7091   4.04060  3.5402
# UC         28.8522  9.6467  0.096501  32.5630   8.8842   7.08840  6.1987
# UC         12.1806  3.1919  6.167000   4.6280  15.0349   0.78703  2.4768
# UC         11.9025  2.8132  0.133530  10.3433   4.8346   3.85200  3.2490
# UC         11.6717  2.8558  0.635620   9.5407  10.0812   0.82951  1.8163
#
#            AC013461.1  AC234582.1     ACAA1  ...  ZNF575    ZNF57  ZNF613  \
# Diagnosis                                    ...
# Control        4.7936    100.4090   91.4398  ...  5.1506   6.7886  5.3642
# Control        6.8132    188.9640   78.0687  ...  8.1902   6.2496  7.4671
# Control        2.6355     92.5353  122.6918  ...  9.1893  10.8217  3.3373
# Control        2.0259    185.8320  103.2063  ...  8.3106   6.6119  5.7008
# Control        6.7774    114.3290   90.3699  ...  4.6946   7.6748  4.5044
# ...               ...         ...       ...  ...     ...      ...     ...
# UC             5.9971   1413.5002   50.9337  ...  2.0813   5.5269  2.0588
# UC             9.1743    481.1641   54.8253  ...  5.7451   7.2663  4.0780
# UC             8.8643   2040.0902   45.0833  ...  1.8492   3.4353  2.3714
# UC             5.7818    184.4920   57.6803  ...  5.2122   6.0640  3.1462
# UC             7.1582   1187.9796   44.2429  ...  2.8300   4.3968  2.2900
#
#             ZNF69   ZNF703   ZNF704  ZNF844    ZNF91   ZNRF3  ZSWIM5
# Diagnosis
# Control    7.1065  38.7633   4.5095  3.7331  20.2813  3.3339  3.6266
# Control    3.8288  20.2415   4.0327  2.4122  13.5649  2.5927  2.2582
# Control    4.9504  32.2447   2.9052  2.7927  17.5972  2.0049  3.2104
# Control    5.3747  34.0843   3.3492  3.1923  13.9003  1.7972  2.8750
# Control    6.7213  33.9893   4.0935  5.3238  22.7351  2.9283  2.4813
# ...           ...      ...      ...     ...      ...     ...     ...
# UC         3.9306  17.1931   2.4215  2.2324  11.1981  1.8088  2.2810
# UC         8.8495  41.5702  10.6617  3.0825  19.4314  3.1041  4.7714
# UC         5.1901  16.3660   3.6026  2.0107  12.9733  1.5402  2.6954
# UC         3.4829  15.4938   3.8959  2.5050  11.5263  1.7130  2.4159
# UC         5.5355  23.4137   3.6767  1.7846  12.9793  2.0435  2.4918
#
# [324 rows x 1882 columns]

# %%
#Max values for all genes and both groups

risk_protectb.max().sort_values().tail(70)
# Out:
# DEFA6       820.4459
# CXCL8       821.0829
# MS4A12      822.1513
# IL1B        832.6782
# REG1B       833.0768
#              ...
# FTH1      10257.0990
# FABP1     12804.5610
# MT-ND3    29355.1050
# MT-CO3    58526.2340
# MT-CO1    73040.0800
# Length: 70, dtype: float64

# %%
#Max values distribution for all genes and both groups

ax = risk_protectb.max().sort_values().plot(kind = 'box', fontsize = 14, figsize = (3,5))
ax.set_xlabel('max values',fontsize = 18)
labe = ''
ax.set_xticklabels(labe)
ax.set_ylabel("Relative gene values", fontsize = 16)
plt.tight_layout()
plt.savefig("max Relative gene values box plot.pdf")
plt.show()

# %%
#Min values for all genes and both groups

risk_protectb.min().sort_values().head(70)
# Out:
# CEACAM4      0.01
# C4BPA        0.01
# SAA2-SAA4    0.01
# SAA2         0.01
# SAA4         0.01
#              ...
# DEFB4B       0.01
# SIGLEC5      0.01
# BHLHA15      0.01
# BEX1         0.01
# KCNJ10       0.01
# Length: 70, dtype: float64

# %%
#Min values distribution for all genes and both groups

ax = risk_protectb.min().sort_values().plot(kind = 'box', fontsize = 14, figsize = (3,5))
ax.set_xlabel('max values',fontsize = 18)
labe = ''
ax.set_xticklabels(labe)
ax.set_ylabel("Relative gene values", fontsize = 16)
plt.tight_layout()
plt.savefig("max Relative gene values box plot.pdf")
plt.show()

# %% [markdown]
# ## Outlier removal and normalization

# %%
from sklearn.preprocessing import FunctionTransformer
#outlirers, zscore
def outliers_zscore(df, b):
  #colms_list = df.columns.to_list()
  #colms_list.remove('Diagnosis')

  for i in df.columns:
     for row in df[i]:
         if row > df[i].quantile(b):
           a = (df[i].replace(to_replace = row, value = 0)).median()
           df[i].replace(to_replace = row, value = a , inplace = True)

  for i in df.columns:
    df[i] = stats.zscore(df[i])

  return df

# %%
outliers_zscore(risk_protectb, 0.9)

# %%
risk_protectb.describe()
# Out:
#               AAMDC          ABAT        ABCA12         ABCB1         ABCC1  \
# count  3.240000e+02  3.240000e+02  3.240000e+02  3.240000e+02  3.240000e+02
# mean   4.814393e-16  3.537979e-16 -2.448316e-16  2.306111e-16  5.914336e-16
# std    1.001547e+00  1.001547e+00  1.001547e+00  1.001547e+00  1.001547e+00
# min   -2.563422e+00 -2.513689e+00 -1.106978e+00 -1.249577e+00 -2.153077e+00
# 25%   -6.746894e-01 -6.499101e-01 -9.847980e-01 -6.398435e-01 -7.999455e-01
# 50%    1.114644e-01  1.955406e-01  4.612643e-02 -9.570958e-02  3.268129e-01
# 75%    3.461108e-01  4.128529e-01  6.052833e-01  1.718611e-02  7.626057e-01
# max    4.276015e+00  3.295229e+00  2.943531e+00  5.683730e+00  1.859674e+00
#
#               ABCG2        ABLIM2    AC013461.1    AC234582.1         ACAA1  \
# count  3.240000e+02  3.240000e+02  3.240000e+02  3.240000e+02  3.240000e+02
# mean  -1.185609e-16  2.590520e-16 -5.996575e-17 -1.508567e-16 -2.528841e-16
# std    1.001547e+00  1.001547e+00  1.001547e+00  1.001547e+00  1.001547e+00
# min   -7.624158e-01 -2.762522e+00 -2.599470e+00 -1.650725e+00 -2.507032e+00
# 25%   -5.611520e-01 -5.893241e-01 -6.754401e-01 -8.584221e-01 -6.203390e-01
# 50%   -2.128922e-01  2.311643e-01  3.507596e-01  1.515027e-01  8.847418e-02
# 75%    4.427118e-02  3.022856e-01  6.131214e-01  6.050538e-01  3.299458e-01
# max    5.323339e+00  3.872661e+00  1.852065e+00  2.437312e+00  3.581348e+00
#
#        ...        ZNF575         ZNF57        ZNF613         ZNF69  \
# count  ...  3.240000e+02  3.240000e+02  3.240000e+02  3.240000e+02
# mean   ... -4.934325e-17 -3.187608e-16  7.428900e-16  2.203313e-16
# std    ...  1.001547e+00  1.001547e+00  1.001547e+00  1.001547e+00
# min    ... -1.968845e+00 -2.420233e+00 -2.812381e+00 -2.727894e+00
# 25%    ... -7.345227e-01 -7.014839e-01 -6.748938e-01 -6.361766e-01
# 50%    ...  1.582597e-01  2.405891e-01  2.513179e-01  2.763070e-01
# 75%    ...  3.218206e-01  4.869557e-01  3.327846e-01  5.656297e-01
# max    ...  3.120139e+00  2.772017e+00  4.232182e+00  2.430761e+00
#
#              ZNF703        ZNF704        ZNF844         ZNF91         ZNRF3  \
# count  3.240000e+02  3.240000e+02  3.240000e+02  3.240000e+02  3.240000e+02
# mean   7.538551e-18  2.193033e-17 -6.561966e-16 -2.515135e-16 -2.330098e-16
# std    1.001547e+00  1.001547e+00  1.001547e+00  1.001547e+00  1.001547e+00
# min   -3.299911e+00 -2.258295e+00 -2.550385e+00 -2.557894e+00 -2.644508e+00
# 25%   -5.700860e-01 -7.299927e-01 -6.315045e-01 -6.452474e-01 -6.431826e-01
# 50%    3.374901e-01  2.105015e-01  3.432650e-01  3.221921e-01  3.058954e-01
# 75%    3.436960e-01  4.943736e-01  5.264585e-01  5.115444e-01  4.793800e-01
# max    3.253010e+00  2.777470e+00  2.803114e+00  3.005735e+00  2.887111e+00
#
#              ZSWIM5
# count  3.240000e+02
# mean   3.597945e-16
# std    1.001547e+00
# min   -2.526601e+00
# 25%   -6.950348e-01
# 50%    3.674439e-01
# 75%    5.716164e-01
# max    2.942403e+00
#
# [8 rows x 1882 columns]

# %%
#Max values for all genes and both groups- after scaling
risk_protectb.max().sort_values().tail(70)
# Out:
# DEFB1       4.663182
# IDO1        4.677609
# PLA2G12B    4.679000
# PAQR5       4.681138
# SLC30A10    4.687487
#               ...
# SLCO1B3     7.076831
# AQP8        7.518429
# PDZK1       7.677394
# LCN15       8.010178
# DEFB4B      8.886629
# Length: 70, dtype: float64

# %%
#Max values distribution for all genes and both groups- after scaling
ax = risk_protectb.max().sort_values().plot(kind = 'box', fontsize = 14, figsize = (3,5))
ax.set_xlabel('min values',fontsize = 18)
labe = ''
ax.set_xticklabels(labe)
ax.set_ylabel("Relative gene values", fontsize = 16)
plt.tight_layout()
plt.savefig("min Relative gene values box plot.pdf")
plt.show()

# %%
#Min values for all genes and both groups- after scaling
risk_protectb.min().sort_values().head(70)
# Out:
# RNF223   -3.898670
# EPHX1    -3.872210
# IGSF8    -3.811129
# SCAP     -3.612739
# CHST12   -3.594614
#             ...
# VILL     -2.986582
# ACVR2A   -2.985405
# ANXA5    -2.985272
# SEC24D   -2.982519
# LY6E     -2.981554
# Length: 70, dtype: float64

# %%
#Min values distribution for all genes and both groups- after scaling
ax = risk_protectb.min().sort_values().plot(kind = 'box', fontsize = 14, figsize = (3,5))
ax.set_xlabel('min values',fontsize = 18)
labe = ''
ax.set_xticklabels(labe)
ax.set_ylabel("Relative gene values", fontsize = 16)
plt.tight_layout()
plt.savefig("min Relative gene values box plot.pdf")
plt.show()

# %%
risk_protectb_avg = risk_protectb.copy()

# %%
#melt so that all gene values will be in one column
risk_protectb_avgT = risk_protectb_avg.groupby('Diagnosis').mean().T
risk_protectb_avgT
# Out:
# Diagnosis   Control        UC
# AAMDC      0.747820 -0.225247
# ABAT       0.596106 -0.179550
# ABCA12    -1.062029  0.319888
# ABCB1      0.744048 -0.224111
# ABCC1     -1.095830  0.330069
# ...             ...       ...
# ZNF704     0.453006 -0.136448
# ZNF844     0.527260 -0.158813
# ZNF91      0.660099 -0.198825
# ZNRF3      0.436256 -0.131402
# ZSWIM5     0.535406 -0.161267
#
# [1882 rows x 2 columns]

# %%
risk_protectb_avgT.min().sort_values()
# Out:
# Diagnosis
# Control   -1.414869
# UC        -0.298424
# dtype: float64

# %%
sns.clustermap(risk_protectb_avgT, figsize=(4, 8),vmin=-1.42, vmax=0.99, yticklabels=False, xticklabels=1)
plt.savefig("HEATMAP DEGs no AVRG outliers.pdf")
plt.show()

# %%
sns.clustermap(risk_protectb_avgT, figsize=(4, 8),vmin=-1.42, vmax=0.99, yticklabels=False, xticklabels=1,cmap='coolwarm')
plt.savefig("HEATMAP DEGs no AVRG outliers.pdf")
plt.show()

# %%
#DEGs expression
sns.clustermap(risk_protectb.T, figsize=(12, 10),vmin=-3.89, vmax=8.89,  yticklabels=False, xticklabels=4)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/matrix.py:654: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
# Clustering data row-wise and
# changing color of the map.
sns.clustermap(risk_protectb.T, cmap='coolwarm',  figsize=(12, 10),vmin=-3.89, vmax=8.89,  yticklabels=False, xticklabels=4)
#plt.tight_layout()
plt.savefig("HEATMAP DEGs no outliers blue.pdf")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/matrix.py:654: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
